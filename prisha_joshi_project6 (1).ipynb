# %% [markdown]
# # Project X -- [Prisha] [Joshi]

# %% [markdown]
# **TA Help:** John Smith, Alice Jones
#
# - Help with figuring out how to write a function.
#
# **Collaboration:** Friend1, Friend2
#
# - Helped figuring out how to load the dataset.
# - Helped debug error with my plot.

# %% [markdown]
# ## Question 1

# %%
# code here 
library(data.table)
df <- fread("/anvil/projects/tdm/data/death_records/DeathRecords.csv")
#plot(table(df$Age[(df$Sex == "F") & (df$Age < 999)]))
#plot(table(df$Age[(df$Sex == "M") & (df$Age < 999)]))
table(df$Race)
plot(table(df$Age[(df$Race == 7) & (df$Age <999)]))
# Out:
#       1       2       3       4       5       6       7      18      28      38
# 2241510  309504   18031   13297    8159     700   11074    6778    4711     623
#      48      58      68      78
#    4913     316    8737    2818
# plot without title

# %% [markdown]
# the table shows us that race value 1 occurs 2241510, 2 = 309504 , 3 = 18031, 4 = 13297,5 =8159 ,6=700 ,7= 11074, 18 = 6778, 28= 4711 , 38 =623, 48= 4913, 58 = 316 , 68 = 8737 , 78= 2818. the filipino race is occured 11074 times
# the pot shows the age at which filipino race died . as we can see the max is between 86 and 94 years.

# %% [markdown]
# ## Question 2

# %%
# code here
library(data.table)
DF <- fread ("/anvil/projects/tdm/data/8451/The_Complete_Journey_2_Master/5000_transactions.csv")
head(DF)
table(DF$STORE_R[(DF$SPEND < 0)])
# Out:
#   BASKET_NUM HSHD_NUM PURCHASE_ PRODUCT_NUM SPEND UNITS STORE_R WEEK_NUM YEAR
# 1  24        1809     03-JAN-16 5817389     -1.50 -1    SOUTH   1        2016
# 2  24        1809     03-JAN-16 5829886     -1.50 -1    SOUTH   1        2016
# 3  34        1253     03-JAN-16  539501      2.19  1    EAST    1        2016
# 4  60        1595     03-JAN-16 5260099      0.99  1    WEST    1        2016
# 5  60        1595     03-JAN-16 4535660      2.50  2    WEST    1        2016
# 6 168        3393     03-JAN-16 5602916      4.50  1    SOUTH   1        2016
# CENTRAL    EAST   SOUTH    WEST
#    2750    3269    2675    3952

# %% [markdown]
# central store has 2750 refunds. east store has 3269 refunds. south store has 2675 refunds and west store has 3952 refunds.

# %% [markdown]
# ## Question 3

# %%
# code here
library(data.table)
myDF <-  fread("/anvil/projects/tdm/data/beer/reviews_sample.csv")
tail(sort(table(myDF$username)))
a <- mean(myDF$score[(myDF$username == "acurtis") & (myDF$score)])
print(a)
# Out:
#        jaydoc   Texasfan549         Sammy   kylehay2004 StonedTrippin
#          1489          1532          1591          1628          1630
#       acurtis
#          1646
# [1] 3.655802

# %% [markdown]
# the 6 most popular reviews are shown above. jaydoc wrote 1489 reviwes, Teaxsfan549 wrote 1532 reviews , Sammy wrote 591 , kylehay2004 wrote 1628 , stonedTrippin wrote 1630 and acurtis wrote 1646 reviews.
# the mean score given by acurtis was a 3.655802

# %% [markdown]
# ## Question 4

# %%
# code here
library(data.table)
myDF <- fread("/anvil/projects/tdm/data/election/itcont1980.txt", quote="")
names(myDF) <- c("CMTE_ID", "AMNDT_IND", "RPT_TP", "TRANSACTION_PGI", "IMAGE_NUM", "TRANSACTION_TP", "ENTITY_TP", "NAME", "CITY", "STATE", "ZIP_CODE", "EMPLOYER", "OCCUPATION", "TRANSACTION_DT", "TRANSACTION_AMT", "OTHER_ID", "TRAN_ID", "FILE_NUM", "MEMO_CD", "MEMO_TEXT", "SUB_ID")
result <- myDF$NAME[!is.na(myDF$NAME) & is.na(myDF$TRANSACTION_DT)]
print(result)
# Out:
# [1] "SCHECK, RICHARD HERBERT" "SCHECK, RICHARD HERBERT"
# [3] "SCHECK, RICHARD HERBERT" "SCHECK, RICHARD HERBERT"
# [5] "SCHECK, RICHARD HERBERT" "SCHECK, RICHARD HERBERT"
# [7] "CURCIO, BARBARA G"       "WOLFF, GARY W."
# [9] "WOLFF, GARY W."

# %% [markdown]
# the nine names for which the transaction data were missing was Richard Herbet Scheck(6), Barbara G Curcio(1), Gary W. Wolff(2).

# %% [markdown]
# ## Question 5

# %%
# code here
library(data.table)
DF1 <- fread("/anvil/projects/tdm/data/flights/subset/1990.csv")
average <- mean(DF1$DepDelay[(DF1$Origin == "EWR") | (DF1$Origin == "LGA")|(DF1$Origin == "JFK")] , na.rm =TRUE)
print(average)
# Out:
# [1] 9.400064

# %% [markdown]
# the mean departure delay of a flight from either of the three given airports was 9.400064

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
